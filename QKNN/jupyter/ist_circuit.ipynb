# %%
import numpy as np
from base import swap_test
from qiskit import QuantumCircuit
from qiskit_aer import Aer
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 import numpy as np
# ----> 2 from base.swaptest import swap_test
#       3 from qiskit import QuantumCircuit
#       4 from qiskit_aer import Aer
#
# ModuleNotFoundError: No module named 'base'

# %%
v1 = [1, 2]
v2 = [1, 2]

P0, P1, F, dist = swap_test(v1, v2)

print("Vector 1:", v1)
print("Vector 2:", v2)
print("P(0) =", P0)
print("P(1) =", P1)
print("Fidelity =", F)
print("Distance =", dist)
# Out:
# Vector 1: [1, 2]
# Vector 2: [1, 2]
# P(0) = 1.0
# P(1) = 0.0
# Fidelity = 1.0
# Distance = 0.0

# %%
v1 = [1, 2]
v2 = [5, 8]

P0, P1, F, dist = swap_test(v1, v2)

print("Vector 1:", v1)
print("Vector 2:", v2)
print("P(0) =", P0)
print("P(1) =", P1)
print("Fidelity =", F)
print("Distance =", dist)
# Out:
# Vector 1: [1, 2]
# Vector 2: [5, 8]
# P(0) = 0.994384765625
# P(1) = 0.005615234375
# Fidelity = 0.98876953125
# Distance = 0.10597390598633231
