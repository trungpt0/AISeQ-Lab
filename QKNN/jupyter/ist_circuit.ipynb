# %%
import sys
sys.path.append("/home/ptsapce/AISeQ-Lab/QKNN")

import numpy as np
from base.swaptest import swap_test
from qiskit import QuantumCircuit
from qiskit_aer import Aer

# %%
v1 = [1, 2]
v2 = [1, 2]

P0, P1, F, dist = swap_test(v1, v2)

print("Vector 1:", v1)
print("Vector 2:", v2)
print("P(0) =", P0)
print("P(1) =", P1)
print("Fidelity =", F)
print("Distance =", dist)
# Out:
# Vector 1: [1, 2]
# Vector 2: [1, 2]
# P(0) = 1.0
# P(1) = 0.0
# Fidelity = 1.0
# Distance = 0.0

# %%
v1 = [1, 2, 3]
v2 = [5, 8, 4]

P0, P1, F, dist = swap_test(v1, v2)

print("Vector 1:", v1)
print("Vector 2:", v2)
print("P(0) =", P0)
print("P(1) =", P1)
print("Fidelity =", F)
print("Distance =", dist)
# Out:
# Vector 1: [1, 2]
# Vector 2: [5, 8]
# P(0) = 0.995361328125
# P(1) = 0.004638671875
# Fidelity = 0.99072265625
# Distance = 0.09631896879639025
