# %%
import sys
sys.path.append("/home/ptsapce/AISeQ-Lab/QKNN")

import numpy as np
from base.knn import KNNClassifier

# %%
Dtrain = np.array([
    [1.0, 2.0, 2.0],
    [1.5, 1.8, 2.1],
    [5.0, 8.0, 1.0],
    [6.0, 8.0, 1.5]
])

Ytrain = np.array([0, 0, 1, 1])

Dtest = np.array([[2.0, 2.0, 1.0], [5.0, 7.0, 3.0]])

# %%
knn = KNNClassifier(k=3)
knn.fit(Dtrain, Ytrain)
predictions = knn.predict(Dtest)
print("Predicted class for Dtest:", predictions)
# Out:
# Predicted class for Dtest: [0 1]
